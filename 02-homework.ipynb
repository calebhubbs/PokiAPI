# %% [markdown]
# Take a look at PokeAPI: <a href="https://pokeapi.co/">https://pokeapi.co/</a>.
#
# On this website you will see an API simulator. Trying any combination of correct possible server requests should yield you a successful result in the scrollable area. In this scrollable area is an exact server response you will get if you sent a response to it.
#
# Click on the `Documentation` tab, then click on v2. On the next page you'll see a bunch of words that seemingly make no sense. Just like with any API, there is documentation showing you how to use it. API documentation, by nature, is very wordy, overwhelming and almost never straightforward. You will find very few APIs that have simple documentation. Once you start to become a mid-senior level engineer, the little details in documentation will make all the difference in the quality of your results. Most people find API documentation difficult to navigate at first. Don't worry, it's normal.
#
# That being said, familiarize yourself with everything in the documentation and try to skim as much as possible to get a feel for where everything is before proceeding.

# %% [markdown]
# <strong>`Objective`</strong>: There are several main Pokemon class types: Fire, Water, Grass, Rock, Electric. Your application will use PokeAPI to build your own API program. Compile a list of 30 total Pokemon that identify as the aforementioned class types. Each category will hold a list of Pokemon and their personal attributes and some statistics as follows. Make this program an object-oriented program:
#
# **Note** How you compile the list of Pokemon is entirely up to you.

# %%
{
    "Electric": {
        "characters": [
            {
                "name": "Pikachu",
                "height": 4,
                "weight": 60,
                "stats": {
                    "health (hp)": 35,
                    "attack": 55,
                    "defense": 40,
                    "speed": 90
                },
                "abilities": [
                    {
                        "name": "lightning-rod"
                    },
                    {
                        "name": "static"
                    }
                ]
            }
        ],
        "statistics": {
            "average height": 55.0,
            "average weight": 55.0,
            "average health": 55.0,
            "average attack": 55.0,
            "average defense": 55.0,
            "average speed": 55.0
        }
    },
    "Water": {
        "characters": [
            { ... }
        ],
        "statistics": { ... }
    }
}

# %%
import requests

charizard = []

data = requests.get('https://pokeapi.co/api/v2/pokemon/charizard').json()

ability = [(data['abilities'][0]['ability']), (data['abilities'][1]['ability']['name'])]
ctype = [data['types'][0]['type']['name']]
height = [data['height']]
weight = [data['weight']]

charizard.append({'types':ctype})
charizard.append({'abilities':ability})
charizard.append({'height':height})
charizard.append({'weight':weight})

charizard

pikachu = []

data = requests.get('https://pokeapi.co/api/v2/pokemon/pikachu').json()

ability = [(data['abilities'][0]['ability']), (data['abilities'][1]['ability']['name'])]
ctype = [data['types'][0]['type']['name']]
height = [data['height']]
weight = [data['weight']]

pikachu.append({'types':ctype})
pikachu.append({'abilities':ability})
pikachu.append({'height':height})
pikachu.append({'weight':weight})

pikachu

blastoise = []

data = requests.get('https://pokeapi.co/api/v2/pokemon/blastoise').json()

ability = [(data['abilities'][0]['ability']), (data['abilities'][1]['ability']['name'])]
ctype = [data['types'][0]['type']['name']]
height = [data['height']]
weight = [data['weight']]

blastoise.append({'types':ctype})
blastoise.append({'abilities':ability})
blastoise.append({'height':height})
blastoise.append({'weight':weight})

blastoise

squirtle = []

data = requests.get('https://pokeapi.co/api/v2/pokemon/squirtle').json()

ability = [(data['abilities'][0]['ability']), (data['abilities'][1]['ability']['name'])]
ctype = [data['types'][0]['type']['name']]
height = [data['height']]
weight = [data['weight']]

squirtle.append({'types':ctype})
squirtle.append({'abilities':ability})
squirtle.append({'height':height})
squirtle.append({'weight':weight})

squirtle

magnemite = []

data = requests.get('https://pokeapi.co/api/v2/pokemon/magnemite').json()

ability = [(data['abilities'][0]['ability']), (data['abilities'][1]['ability']['name'])]
ctype = [data['types'][0]['type']['name']]
height = [data['height']]
weight = [data['weight']]

magnemite.append({'types':ctype})
magnemite.append({'abilities':ability})
magnemite.append({'height':height})
magnemite.append({'weight':weight})

magnemite

voltorb = []

data = requests.get('https://pokeapi.co/api/v2/pokemon/voltorb').json()

ability = [(data['abilities'][0]['ability']), (data['abilities'][1]['ability']['name'])]
ctype = [data['types'][0]['type']['name']]
height = [data['height']]
weight = [data['weight']]

voltorb.append({'types':ctype})
voltorb.append({'abilities':ability})
voltorb.append({'height':height})
voltorb.append({'weight':weight})

voltorb

starmie = []

data = requests.get('https://pokeapi.co/api/v2/pokemon/starmie').json()

ability = [(data['abilities'][0]['ability']), (data['abilities'][1]['ability']['name'])]
ctype = [data['types'][0]['type']['name']]
height = [data['height']]
weight = [data['weight']]

starmie.append({'types':ctype})
starmie.append({'abilities':ability})
starmie.append({'height':height})
starmie.append({'weight':weight})

starmie

pineco = []

data = requests.get('https://pokeapi.co/api/v2/pokemon/pineco').json()

ability = [(data['abilities'][0]['ability']), (data['abilities'][1]['ability']['name'])]
ctype = [data['types'][0]['type']['name']]
height = [data['height']]
weight = [data['weight']]

pineco.append({'types':ctype})
pineco.append({'abilities':ability})
pineco.append({'height':height})
pineco.append({'weight':weight})

pineco

orbeetle = []

data = requests.get('https://pokeapi.co/api/v2/pokemon/orbeetle').json()

ability = [(data['abilities'][0]['ability']), (data['abilities'][1]['ability']['name'])]
ctype = [data['types'][0]['type']['name']]
height = [data['height']]
weight = [data['weight']]

orbeetle.append({'types':ctype})
orbeetle.append({'abilities':ability})
orbeetle.append({'height':height})
orbeetle.append({'weight':weight})

orbeetle

ponyta = []

data = requests.get('https://pokeapi.co/api/v2/pokemon/ponyta').json()

ability = [(data['abilities'][0]['ability']), (data['abilities'][1]['ability']['name'])]
ctype = [data['types'][0]['type']['name']]
height = [data['height']]
weight = [data['weight']]

ponyta.append({'types':ctype})
ponyta.append({'abilities':ability})
ponyta.append({'height':height})
ponyta.append({'weight':weight})

ponyta

charmander = []

data = requests.get('https://pokeapi.co/api/v2/pokemon/charmander').json()

ability = [(data['abilities'][0]['ability']), (data['abilities'][1]['ability']['name'])]
ctype = [data['types'][0]['type']['name']]
height = [data['height']]
weight = [data['weight']]

charmander.append({'types':ctype})
charmander.append({'abilities':ability})
charmander.append({'height':height})
charmander.append({'weight':weight})

charmander

magmar = []

data = requests.get('https://pokeapi.co/api/v2/pokemon/magmar').json()

ability = [(data['abilities'][0]['ability']), (data['abilities'][1]['ability']['name'])]
ctype = [data['types'][0]['type']['name']]
height = [data['height']]
weight = [data['weight']]

magmar.append({'types':ctype})
magmar.append({'abilities':ability})
magmar.append({'height':height})
magmar.append({'weight':weight})

magmar

electrode = []

data = requests.get('https://pokeapi.co/api/v2/pokemon/electrode').json()

ability = [(data['abilities'][0]['ability']), (data['abilities'][1]['ability']['name'])]
ctype = [data['types'][0]['type']['name']]
height = [data['height']]
weight = [data['weight']]

electrode.append({'types':ctype})
electrode.append({'abilities':ability})
electrode.append({'height':height})
electrode.append({'weight':weight})

electrode

gogoat = []

data = requests.get('https://pokeapi.co/api/v2/pokemon/gogoat').json()

ability = [(data['abilities'][0]['ability']), (data['abilities'][1]['ability']['name'])]
ctype = [data['types'][0]['type']['name']]
height = [data['height']]
weight = [data['weight']]

gogoat.append({'types':ctype})
gogoat.append({'abilities':ability})
gogoat.append({'height':height})
gogoat.append({'weight':weight})

gogoat

seel = []

data = requests.get('https://pokeapi.co/api/v2/pokemon/seel').json()

ability = [(data['abilities'][0]['ability']), (data['abilities'][1]['ability']['name'])]
ctype = [data['types'][0]['type']['name']]
height = [data['height']]
weight = [data['weight']]

seel.append({'types':ctype})
seel.append({'abilities':ability})
seel.append({'height':height})
seel.append({'weight':weight})

seel

diglett = []

data = requests.get('https://pokeapi.co/api/v2/pokemon/diglett').json()
ditto
ability = [(data['abilities'][0]['ability']), (data['abilities'][1]['ability']['name'])]
ctype = [data['types'][0]['type']['name']]
height = [data['height']]
weight = [data['weight']]

diglett.append({'types':ctype})
diglett.append({'abilities':ability})
diglett.append({'height':height})
diglett.append({'weight':weight})

diglett

sandshrew = []

data = requests.get('https://pokeapi.co/api/v2/pokemon/sandshrew').json()

ability = [(data['abilities'][0]['ability']), (data['abilities'][1]['ability']['name'])]
ctype = [data['types'][0]['type']['name']]
height = [data['height']]
weight = [data['weight']]

sandshrew.append({'types':ctype})
sandshrew.append({'abilities':ability})
sandshrew.append({'height':height})
sandshrew.append({'weight':weight})

sandshrew

sandslash = []

data = requests.get('https://pokeapi.co/api/v2/pokemon/sandslash').json()

ability = [(data['abilities'][0]['ability']), (data['abilities'][1]['ability']['name'])]
ctype = [data['types'][0]['type']['name']]
height = [data['height']]
weight = [data['weight']]

sandslash.append({'types':ctype})
sandslash.append({'abilities':ability})
sandslash.append({'height':height})
sandslash.append({'weight':weight})

sandslash

bulbasaur = []

data = requests.get('https://pokeapi.co/api/v2/pokemon/bulbasaur').json()

ability = [(data['abilities'][0]['ability']), (data['abilities'][1]['ability']['name'])]
ctype = [data['types'][0]['type']['name']]
height = [data['height']]
weight = [data['weight']]

bulbasaur.append({'types':ctype})
bulbasaur.append({'abilities':ability})
bulbasaur.append({'height':height})
bulbasaur.append({'weight':weight})

bulbasaur

venusaur = []

data = requests.get('https://pokeapi.co/api/v2/pokemon/venusaur').json()

ability = [(data['abilities'][0]['ability']), (data['abilities'][1]['ability']['name'])]
ctype = [data['types'][0]['type']['name']]
height = [data['height']]
weight = [data['weight']]

venusaur.append({'types':ctype})
venusaur.append({'abilities':ability})
venusaur.append({'height':height})
venusaur.append({'weight':weight})

venusaur


geodude = []

data = requests.get('https://pokeapi.co/api/v2/pokemon/geodude').json()

ability = [(data['abilities'][0]['ability']), (data['abilities'][1]['ability']['name'])]
ctype = [data['types'][0]['type']['name']]
height = [data['height']]
weight = [data['weight']]

geodude.append({'types':ctype})
geodude.append({'abilities':ability})
geodude.append({'height':height})
geodude.append({'weight':weight})

geodude


onix = []

data = requests.get('https://pokeapi.co/api/v2/pokemon/onix').json()

ability = [(data['abilities'][0]['ability']), (data['abilities'][1]['ability']['name'])]
ctype = [data['types'][0]['type']['name']]
height = [data['height']]
weight = [data['weight']]

onix.append({'types':ctype})
onix.append({'abilities':ability})
onix.append({'height':height})
onix.append({'weight':weight})

onix

graveler = []

data = requests.get('https://pokeapi.co/api/v2/pokemon/graveler').json()

ability = [(data['abilities'][0]['ability']), (data['abilities'][1]['ability']['name'])]
ctype = [data['types'][0]['type']['name']]
height = [data['height']]
weight = [data['weight']]

graveler.append({'types':ctype})
graveler.append({'abilities':ability})
graveler.append({'height':height})
graveler.append({'weight':weight})

graveler
# Out:
# [{'types': ['rock']},
#  {'abilities': [{'name': 'rock-head',
#     'url': 'https://pokeapi.co/api/v2/ability/69/'},
#    'sturdy']},
#  {'height': [10]},
#  {'weight': [1050]}]

# %%
pokedex = {}
pokedex['charizard'] = charizard
pokedex['pikachu'] = pikachu
pokedex['blastoise'] = blastoise
pokedex['squritle'] = squirtle
pokedex['magnemite'] = magnemite
pokedex['voltorb'] = voltorb
pokedex['starmie'] = starmie
pokedex['pineco'] = pineco
pokedex['orbeetle'] = orbeetle
pokedex['ponyta'] = ponyta
pokedex['charmander'] = charmander
pokedex['magmar'] = magmar
pokedex['gogoat'] = gogoat
pokedex['seel'] = seel
pokedex['diglett'] = diglett
pokedex['sandshrew'] = sandshrew
pokedex['sandslash'] = sandslash
pokedex['bulbasaur'] = bulbasaur
pokedex['venusaur'] = venusaur
pokedex['geodude'] = geodude
pokedex['onix'] = onix
pokedex['graveler'] = graveler

pokedex
# Out:
# {'charizard': [{'types': ['fire']},
#   {'abilities': [{'name': 'blaze',
#      'url': 'https://pokeapi.co/api/v2/ability/66/'},
#     'solar-power']},
#   {'height': [17]},
#   {'weight': [905]}],
#  'pikachu': [{'types': ['electric']},
#   {'abilities': [{'name': 'static',
#      'url': 'https://pokeapi.co/api/v2/ability/9/'},
#     'lightning-rod']},
#   {'height': [4]},
#   {'weight': [60]}],
#  'blastoise': [{'types': ['water']},
#   {'abilities': [{'name': 'torrent',
#      'url': 'https://pokeapi.co/api/v2/ability/67/'},
#     'rain-dish']},
#   {'height': [16]},
#   {'weight': [855]}],
#  'squritle': [{'types': ['water']},
#   {'abilities': [{'name': 'torrent',
#      'url': 'https://pokeapi.co/api/v2/ability/67/'},
#     'rain-dish']},
#   {'height': [5]},
#   {'weight': [90]}],
#  'magnemite': [{'types': ['electric']},
#   {'abilities': [{'name': 'magnet-pull',
#      'url': 'https://pokeapi.co/api/v2/ability/42/'},
#     'sturdy']},
#   {'height': [3]},
# ...

# %%
class Pokemon:
    def __init__(self, name, abilities, height, weight):
        self.name = name
        self.abilities = abilities
        self.height = height
        self.weight = weight
        
        #Not sure if I should right an if statement for this init part
    
    def __repr__(self):
        return f'<Pokemon: {self.name}>
    


class Pokedex: 
    _list = []
    
    @classmethod
    def instructions(self):
        print("""This is the Pokedex.
Type 'show' to view pokedex.
Type 'quit' to exit the pokedex.
Type 'sort' to view the categorized pokedex""")
    
    @classmethod
    def populate(self, name): 
        if Pokedex._list: 
            for p in Pokedex._list: 
                if name.title() == p.name: 
                    input("This Pokeman is already in your Pokedex, try another Pokemon!")
        try: 
            print("Please wait while we update the Pokedex")
            # you'd want to have it where it updates the Pokedex with a new pokemon if it is in the link 
            # res = requests.get(f'https://pokeapi.co/api/v2/pokemon/{name}').json()
            # p = Pokemon()
            # 
            # data = { 
            # ability = [(data['abilities'][0]['ability']), (data['abilities'][1]['ability']['name'])]
# ctype = [data['types'][0]['type']['name']]
# height = [res['height']]
# weight = [res['weight']]
# }
    def show(self):

# %%
import requests, json

p
# Out:
# <Response [200]>
